# %%
import pymongo

#only works by creating api key in authentication settings in realm (can't use email/password)
# provide your api key  
client = pymongo.MongoClient("mongodb://_:MC1oIOHEeuFFAsL4Rip4cmQygmZsUKYQ8RK1zTGdK950FZOPjLaWuIDmWQcbV6nb@realm.mongodb.com:27020/?authMechanism=PLAIN&authSource=%24external&ssl=true&appName=application-1-yyoku:mongodb-atlas:api-key")
client
# Out:
# MongoClient(host=['realm.mongodb.com:27020'], document_class=dict, tz_aware=False, connect=True, authmechanism='PLAIN', authsource='$external', appname='application-1-yyoku:mongodb-atlas:api-key', tls=True)

# %%
# read db
Project = client["HandM"]
collection = Project.get_collection("H_M")

# %%
RandO= Project.command("callFunction", "RedAndOrange")
RandO['response']
# Out:
# [{'product_type_name': 'Leggings/Tights',
#   'perceived_colour_master_name': 'Red'},
#  {'product_type_name': 'Hair clip', 'perceived_colour_master_name': 'Orange'},
#  {'product_type_name': 'Hair/alice band',
#   'perceived_colour_master_name': 'Orange'},
#  {'product_type_name': 'Socks', 'perceived_colour_master_name': 'Red'},
#  {'product_type_name': 'Hair clip', 'perceived_colour_master_name': 'Orange'},
#  {'product_type_name': 'Swimsuit', 'perceived_colour_master_name': 'Red'},
#  {'product_type_name': 'Swimsuit', 'perceived_colour_master_name': 'Orange'},
#  {'product_type_name': 'Swimsuit', 'perceived_colour_master_name': 'Red'},
#  {'product_type_name': 'Skirt', 'perceived_colour_master_name': 'Red'},
#  {'product_type_name': 'Sweater', 'perceived_colour_master_name': 'Red'},
#  {'product_type_name': 'Sweater', 'perceived_colour_master_name': 'Orange'},
#  {'product_type_name': 'Vest top', 'perceived_colour_master_name': 'Red'},
#  {'product_type_name': 'Underwear Tights',
# ...

# %%
case= Project.command("callFunction", "CASE", arguments=["ladieswear","black"])

# %%
len(case['response'])
# Out:
# 10188

# %%
case['response']
# Out:
# [{'_id': ObjectId('62ac80239a5ae2890b665a8b'),
#   'article_id': 108775015,
#   'product_code': 108775,
#   'prod_name': 'Strap top',
#   'product_type_no': 253,
#   'product_type_name': 'Vest top',
#   'product_group_name': 'Garment Upper body',
#   'graphical_appearance_no': 1010016,
#   'graphical_appearance_name': 'Solid',
#   'colour_group_code': 9,
#   'colour_group_name': 'Black',
#   'perceived_colour_value_id': 4,
#   'perceived_colour_value_name': 'Dark',
#   'perceived_colour_master_id': 5,
#   'perceived_colour_master_name': 'Black',
#   'department_no': 1676,
#   'department_name': 'Jersey Basic',
#   'index_code': 'A',
#   'index_name': 'Ladieswear',
#   'index_group_no': 1,
#   'index_group_name': 'Ladieswear',
#   'section_no': 16,
#   'section_name': 'Womens Everyday Basics',
#   'garment_group_no': 1002,
#   'garment_group_name': 'Jersey Basic',
#   'detail_desc': 'Jersey top with narrow shoulder straps.',
#   'price': 169.52,
#   'discount_%': 10},
# ...

# %%
array= Project.command("callFunction", "ARRAY", arguments=["Vest top", "Black", [90, 200]])

# %%
len(array['response'])
# Out:
# 399

# %%
array['response']
# Out:
# [{'product_type_name': 'Vest top',
#   'colour_group_name': 'Black',
#   'department_name': 'Jersey Basic',
#   'price': 169.52,
#   'discount_%': 10},
#  {'product_type_name': 'Vest top',
#   'colour_group_name': 'Black',
#   'department_name': 'Kids Boy Jersey Basic',
#   'price': 118.31,
#   'discount_%': 5},
#  {'product_type_name': 'Vest top',
#   'colour_group_name': 'Black',
#   'department_name': 'Jersey Basic',
#   'price': 90.48,
#   'discount_%': 10},
#  {'product_type_name': 'Vest top',
#   'colour_group_name': 'Black',
#   'department_name': 'Kids Girl UW/NW',
#   'price': 166.53,
#   'discount_%': 0},
#  {'product_type_name': 'Vest top',
#   'colour_group_name': 'Black',
#   'department_name': 'Basic 1',
#   'price': 116.27,
#   'discount_%': 0},
#  {'product_type_name': 'Vest top',
#   'colour_group_name': 'Black',
#   'department_name': 'Basic 1',
#   'price': 161.89,
#   'discount_%': 20},
#  {'product_type_name': 'Vest top',
#   'colour_group_name': 'Black',
# ...

# %%
DiscPrice= Project.command("callFunction", "DiscountPrice")
DiscPrice['response']
# Out:
# [{'price': 5.06, 'New_price': 3.542},
#  {'price': 5.07, 'New_price': 3.5490000000000004},
#  {'price': 5.08, 'New_price': 3.556},
#  {'price': 5.08, 'New_price': 3.556},
#  {'price': 5.14, 'New_price': 3.598},
#  {'price': 5.28, 'New_price': 3.696},
#  {'price': 5.34, 'New_price': 3.738},
#  {'price': 5.35, 'New_price': 3.745},
#  {'price': 5.38, 'New_price': 3.766},
#  {'price': 5.47, 'New_price': 3.8289999999999997},
#  {'price': 5.12, 'New_price': 3.84},
#  {'price': 5.12, 'New_price': 3.84},
#  {'price': 5.14, 'New_price': 3.8549999999999995},
#  {'price': 5.52, 'New_price': 3.864},
#  {'price': 5.18, 'New_price': 3.885},
#  {'price': 5.26, 'New_price': 3.945},
#  {'price': 5.27, 'New_price': 3.9524999999999997},
#  {'price': 5.34, 'New_price': 4.005},
#  {'price': 5.35, 'New_price': 4.012499999999999},
#  {'price': 5.74, 'New_price': 4.018000000000001},
#  {'price': 5.03, 'New_price': 4.024},
#  {'price': 5.03, 'New_price': 4.024},
#  {'price': 5.37, 'New_price': 4.0275},
# ...

# %%
allsearch= Project.command("callFunction", "allSearch", arguments=["Solid"])

# %%
allsearch['response']
# Out:
# [{'prod_name': 'Strap top',
#   'product_type_name': 'Vest top',
#   'product_group_name': 'Garment Upper body',
#   'graphical_appearance_name': 'Solid',
#   'colour_group_name': 'Black',
#   'perceived_colour_value_name': 'Dark',
#   'perceived_colour_master_name': 'Black',
#   'department_name': 'Jersey Basic',
#   'index_code': 'A',
#   'index_name': 'Ladieswear',
#   'index_group_name': 'Ladieswear',
#   'section_name': 'Womens Everyday Basics',
#   'garment_group_name': 'Jersey Basic',
#   'detail_desc': 'Jersey top with narrow shoulder straps.',
#   'price': 169.52,
#   'discount_%': 10},
#  {'prod_name': 'Strap top',
#   'product_type_name': 'Vest top',
#   'product_group_name': 'Garment Upper body',
#   'graphical_appearance_name': 'Solid',
#   'colour_group_name': 'White',
#   'perceived_colour_value_name': 'Light',
#   'perceived_colour_master_name': 'White',
#   'department_name': 'Jersey Basic',
#   'index_code': 'A',
#   'index_name': 'Ladieswear',
# ...
